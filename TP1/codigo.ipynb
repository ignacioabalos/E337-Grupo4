# %% [markdown]
# # Trabajo Practico 1
# ## Grupo 4

# %%
# Seteo el directorio
import os
os.chdir("/Users/ignacioabalos/Desktop/TP 1  big data/")

# %%
# Voy a abrir las bases de datos. Para eso importo la libreria pandas
import pandas as pd

# Comienzo importanto la del primer trimestre de 2024
df2024 = pd.read_excel("usu_individual_T124.xlsx")

# Chequeo
df2024.sample(5)

# %%
# Ahora abri la de 2004
df

# %%
df2024.head(10)
# Out:
#                           CODUSU  ANO4  TRIMESTRE  NRO_HOGAR  COMPONENTE  H15  \
# 0  TQRMNOPUTHLMKQCDEGGFB00852588  2024          1          1           3    1
# 1  TQRMNOPUTHLMKQCDEGGFB00852588  2024          1          1           4    1
# 2  TQRMNOPUTHLMKQCDEGGFB00852588  2024          1          1           5    0
# 3  TQRMNOPPWHLLKRCDEGGFB00852574  2024          1          1           1    1
# 4  TQRMNOPPWHLLKRCDEGGFB00852574  2024          1          1           2    1
# 5  TQRMNOPPWHLLKRCDEGGFB00852574  2024          1          1           3    1
# 6  TQRMNOPPWHLLKRCDEGGFB00852574  2024          1          1           4    1
# 7  TQRMNORSVHKMKNCDEFNFF00856879  2024          1          1           1    1
# 8  TQRMNORSVHKMKNCDEFNFF00856879  2024          1          1           2    1
# 9  TQRMNORSVHKMKNCDEFNFF00856879  2024          1          1           3    1
#
#    REGION MAS_500  AGLOMERADO  PONDERA  ...  PDECIFR  ADECIFR      IPCF  \
# ...
